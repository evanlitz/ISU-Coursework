# %%
# !pip install pymongo # please comment this line before submission
# import all libs (do not change)
# @author Evan Litzer
from pymongo import MongoClient
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import json
import pymongo
import pprint
import nbformat
from nbconvert.preprocessors import ExecutePreprocessor

# %%
# fill in uri (5pts)
uri = "mongodb://localhost:27017/"
# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))
# Send a ping to confirm a successful connection
try:
    capture = client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!", capture)
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB! {'ok': 1.0}

# %%
# database (do not change)
db = client['test']

if 'litcovidtest' in db.list_collection_names():
    db['litcovidtest'].drop()

posts = db['litcovidtest']

# %%
# Loading or Opening the json file
with open('data/litcovid2BioCJSON_small.json') as file:
    file_data = json.load(file)

# Inserting the loaded data in the Collection
# if JSON contains data more than one entry
# insert_many is used else insert_one is used
# fill in (5 pts)

# Insert into MongoDB
if isinstance(file_data, list):
    posts.insert_many(file_data)
else:
    posts.insert_one(file_data)

# %%
# Count the number of documents in this corpus
# fill in (10 pts)
result1= posts.count_documents({})
print("Count the number of documents in this corpus", result1)
# Out:
# Count the number of documents in this corpus 1000

# %%
# find the fields for the first document in this corpus
# fill in (10 pts)
result2= posts.find_one()
pprint.pprint(result2)
# Out:
# {'_id': '32911311|PMC7832150',
#  'authors': ['Gupta NA', 'Lien C', 'Iv M'],
#  'id': '7832150',
#  'infons': {},
#  'journal': 'Clin Imaging',
#  'passages': [{'infons': {'article-id_doi': '10.1016/j.clinimag.2020.08.029',
#                           'article-id_pii': 'S0899-7071(20)30332-6',
#                           'article-id_pmc': '7832150',
#                           'article-id_pmid': '32911311',
#                           'authors': 'Gupta NA, Lien C, Iv M, ',
#                           'fpage': '239',
#                           'journal': 'Clin Imaging; 2020 Dec ; 68 239-241. '
#                                      'doi:10.1016/j.clinimag.2020.08.029',
#                           'kwd': 'Cerebral microbleeds COVID-19 Neuroimaging',
#                           'license': 'Since January 2020 Elsevier has created '
#                                      'a COVID-19 resource centre with free '
#                                      'information in English and Mandarin on '
#                                      'the novel coronavirus COVID-19. The '
#                                      'COVID-19 resource centre is hosted on '
#                                      "Elsevier Connect, the company's public "
#                                      'news and information website. Elsevier '
#                                      'hereby grants permission to make all its '
#                                      'COVID-19-related research that is '
#                                      'available on the COVID-19 resource '
#                                      'centre - including this research content '
#                                      '- immediately available in PubMed '
#                                      'Central and other publicly funded '
#                                      'repositories, such as the WHO COVID '
#                                      'database with rights for unrestricted '
#                                      'research re-use and analyses in any form '
#                                      'or by any means with acknowledgement of '
#                                      'the original source. These permissions '
#                                      'are granted for free by Elsevier for as '
#                                      'long as the COVID-19 resource centre '
#                                      'remains active.',
#                           'lpage': '241',
#                           'name_0': 'surname:Gupta;given-names:Nidhi Azad',
#                           'name_1': 'surname:Lien;given-names:Conway',
#                           'name_2': 'surname:Iv;given-names:Michael',
#                           'section': 'Title',
#                           'section_type': 'TITLE',
#                           'title': 'Keywords',
#                           'type': 'front',
#                           'volume': '68',
#                           'year': '2020'},
#                'offset': 0,
#                'text': 'Critical illness-associated cerebral microbleeds in '
#                        'severe COVID-19 infection '},
#               {'infons': {'section': 'Abstract',
#                           'section_type': 'ABSTRACT',
#                           'type': 'abstract'},
#                'offset': 81,
#                'text': 'Neurologic complications of COVID-19 infection have '
#                        'been recently described and include dizziness, '
#                        'headache, loss of taste and smell, stroke, and '
#                        'encephalopathy. Brain MRI in these patients have '
#                        'revealed various findings including ischemia, '
#                        'hemorrhage, inflammation, and demyelination. In this '
#                        'article, we report a case of critical '
#                        'illness-associated cerebral microbleeds identified on '
#                        'MRI in a patient with severe COVID-19 infection and '
#                        'discuss the potential etiologies of these neuroimaging '
#                        'findings.'},
#               {'infons': {'section': 'Abstract',
#                           'section_type': 'ABSTRACT',
#                           'type': 'abstract_title_1'},
#                'offset': 584,
#                'text': 'Highlights'},
#               {'infons': {'section': 'Abstract',
#                           'section_type': 'ABSTRACT',
#                           'type': 'abstract'},
#                'offset': 595,
#                'text': 'Neurological symptoms are common in patients with '
#                        'COVID-19.'},
#               {'infons': {'section': 'Abstract',
#                           'section_type': 'ABSTRACT',
#                           'type': 'abstract'},
#                'offset': 655,
#                'text': 'Critical illness-associated cerebral microbleeds can '
#                        'be seen in the setting of severe COVID-19.'},
#               {'infons': {'section': 'Abstract',
#                           'section_type': 'ABSTRACT',
#                           'type': 'abstract'},
#                'offset': 751,
#                'text': 'Critical illness-associated cerebral microbleeds are a '
#                        'neuroimaging finding thought to be related to '
#                        'hypoxemia, ECMO-related complications and/or DIC.'},
#               {'infons': {'section': 'Abstract',
#                           'section_type': 'ABSTRACT',
#                           'type': 'abstract'},
#                'offset': 902,
#                'text': 'In patients with severe COVID-19, other potential '
#                        'etiologies of cerebral microbleeds are '
#                        'endotheliopathy, encephalitis and immune response.'},
#               {'infons': {'section': 'Introduction',
#                           'section_type': 'INTRO',
#                           'type': 'title_1'},
#                'offset': 1042,
#                'text': 'Introduction'},
#               {'infons': {'section': 'Introduction',
#                           'section_type': 'INTRO',
#                           'type': 'paragraph'},
#                'offset': 1055,
#                'text': 'Severe acute respiratory distress syndrome due to '
#                        'novel coronavirus (SARS-CoV-2), which was first '
#                        'diagnosed in Wuhan, China in December 2019, is known '
#                        'for its typical clinical manifestations of fever, '
#                        'cough, and fatigue. However, recent studies have '
#                        'described clinical neurological manifestations of '
#                        'coronavirus disease 2019 (COVID-19), which include '
#                        'dizziness, headache, taste and smell impairment, acute '
#                        'cerebrovascular disease, impaired consciousness, '
#                        'seizure, encephalopathy, confusion, agitation, and '
#                        'corticospinal tract signs. Neurological symptoms have '
#                        'been identified more commonly in those with severe or '
#                        'critical infection, with a prevalence ranging from 15% '
#                        'to 36.4%. Reported neuroimaging features have included '
#                        'infarcts, hemorrhages, parenchymal (cortical and/or '
#                        'white matter) T2 FLAIR hyperintensity with or without '
#                        'restricted diffusion, cerebral venous thrombosis, '
#                        'acute hemorrhagic necrotizing encephalopathy, '
#                        'leptomeningeal enhancement, and demyelinating lesions. '
#                        'In critically ill patients, hypoxemia and respiratory '
#                        'failure have been associated with the presence of '
#                        'cerebral microbleeds, which are typically identified '
#                        'as small hypointense foci on T2*-weighted imaging '
#                        '[such as gradient recalled echo (GRE) and '
#                        'susceptibility weighted imaging (SWI)], an MRI '
#                        'sequence that is sensitive to the susceptibility '
#                        'effects of iron within blood products. Of the '
#                        'T2*-weighted sequences, SWI is more sensitive and '
#                        'reliable than GRE for detecting microbleeds, owing to '
#                        'higher signal contrast and spatial resolution. On '
#                        'histopathology, these microbleeds have been shown to '
#                        'contain focal accumulations of hemosiderin-laden '
#                        'macrophages. Herein, we report a case of critical '
#                        'illness-associated cerebral microbleeds in a patient '
#                        'with severe COVID-19 infection and discuss the '
#                        'potential etiologies of these neuroimaging findings.'},
#               {'infons': {'section': 'Case report',
#                           'section_type': 'CASE',
#                           'type': 'title_1'},
#                'offset': 2886,
#                'text': 'Case report'},
#               {'infons': {'file': 'gr1_lrg.jpg',
#                           'id': 'f0005',
#                           'section': 'Case report',
#                           'section_type': 'FIG',
#                           'type': 'fig_caption'},
#                'offset': 2898,
#                'text': 'MRI shows diffuse microbleeds in the bilateral '
#                        'subcortical white matter, basal ganglia, corpus '
#                        'callosum, and brainstem on two-dimensional gradient '
#                        'recalled echo (GRE) (A-C), without any corresponding '
#                        'signal abnormality on T2 FLAIR (D) or '
#                        'diffusion-weighted (E) images.'},
#               {'infons': {'file': 'gr1_lrg.jpg',
#                           'id': 'f0005',
#                           'section': 'Case report',
#                           'section_type': 'FIG',
#                           'type': 'fig'},
#                'offset': 3169,
#                'text': 'Fig. 1'},
#               {'infons': {'section': 'Case report',
#                           'section_type': 'CASE',
#                           'type': 'paragraph'},
#                'offset': 3176,
#                'text': 'A male in his mid-forties presented to the emergency '
#                        'room with cough, shortness of breath, and intermittent '
#                        'fever for two weeks. He quickly became hypoxic with an '
#                        'oxygen saturation of 84% and was subsequently '
#                        'intubated and admitted to the intensive care unit for '
#                        'higher care. Initial tests for influenza, SARS-CoV-2, '
#                        'and other viruses were negative; however, given high '
#                        'clinical suspicion, he was re-tested for SARS-CoV-2 on '
#                        'day 2 of hospital admission and was confirmed to be '
#                        'positive. The patient developed increasing FIO2 '
#                        'requirements and was placed on extracorporeal membrane '
#                        'oxygenation (ECMO). After continued respiratory and '
#                        'ventilation management, he slowly improved with '
#                        'discontinuation of ECMO and extubation by day 23. '
#                        'However, he remained confused and disoriented, and a '
#                        'brain MRI was obtained. MRI revealed diffuse '
#                        'microhemorrhages in the bilateral subcortical white '
#                        'matter, basal ganglia, corpus callosum, brainstem, and '
#                        'cerebellum without corresponding signal abnormality on '
#                        'T2 FLAIR or diffusion-weighted imaging (DWI) (Fig. 1 '
#                        '). Based on his initial and follow-up laboratory tests '
#                        'over the span of five days, he did not meet criteria '
#                        'for overt disseminated intravascular coagulation '
#                        '(DIC), with only slightly increasing D-dimer (0.32 to '
#                        '3.01 mg/L) and decreasing fibrinogen (847 to 490 '
#                        'mg/dL) but normal prothrombin time and platelets. He '
#                        'also had a normal CRP of 46.7 mg/dL. Lumbar puncture '
#                        'was not performed. Supportive treatment was continued, '
#                        "and the patient's respiratory status and neurological "
#                        'exam improved. He was discharged to a skilled nursing '
#                        'facility on day 41.'},
#               {'infons': {'section': 'Discussion',
#                           'section_type': 'DISCUSS',
#                           'type': 'title_1'},
#                'offset': 4771,
#                'text': 'Discussion'},
#               {'infons': {'section': 'Discussion',
#                           'section_type': 'DISCUSS',
#                           'type': 'paragraph'},
#                'offset': 4782,
#                'text': 'Critical illness-associated cerebral microbleeds have '
#                        'been reported in patients with high altitude cerebral '
#                        'edema (HACE), acute respiratory failure, and in those '
#                        'requiring ECMO. They can extensively involve the '
#                        'juxtacortical white matter and corpus callosum (often '
#                        'the splenium) and less frequently involve the cortex '
#                        'and deep and periventricular white matter. The '
#                        'etiology of these microbleeds is likely related to one '
#                        'or more of the following processes: 1) hypoxia-induced '
#                        'effects on the blood-brain barrier resulting in '
#                        'extravasation of blood, 2) potential side effects of '
#                        'ECMO therapy such as gas embolism or coagulopathy, and '
#                        '3) disseminated intravascular coagulation.'},
#               {'infons': {'section': 'Discussion',
#                           'section_type': 'DISCUSS',
#                           'type': 'paragraph'},
#                'offset': 5456,
#                'text': 'Hypoxia is a common factor for the development of '
#                        'microbleeds in patients with acute respiratory '
#                        'failure. The likely pathogenesis is a hydrostatic- or '
#                        'chemical-related disruption of the blood-brain '
#                        'barrier, which leads to extravasation of red blood '
#                        'cells. The presence of cerebral venous hypertension, '
#                        'which is also suspected to play an important role in '
#                        'HACE, may further contribute to increased capillary '
#                        'stress and permeability. HACE is a life-threatening '
#                        'illness due to hypoxemia at high altitudes and is '
#                        'characterized by severe ataxia and altered '
#                        'consciousness; consequently, it can result in death '
#                        'within 24 to 48 hours from vasogenic cerebral edema '
#                        'and brain herniation. Neuroimaging in patients with '
#                        'HACE include microhemorrhages in the juxtacortical '
#                        'white matter and corpus callosum, often in a splenial '
#                        'distribution. Similarly, brain MRIs in patients '
#                        'without HACE but with severe acute respiratory '
#                        'distress syndrome (including those with morphine '
#                        'intoxication and chronic obstructive pulmonary disease '
#                        'on mechanical ventilation) have shown disseminated '
#                        'microhemorrhages in the same distribution. In the '
#                        'setting of patients with severe or critical COVID-19 '
#                        'infection, small case series have shown a similar '
#                        'pattern of isolated or extensive cerebral microbleeds '
#                        'in the white matter and corpus callosum.'},
#               {'infons': {'section': 'Discussion',
#                           'section_type': 'DISCUSS',
#                           'type': 'paragraph'},
#                'offset': 6768,
#                'text': 'Supportive measures used in patients with severe '
#                        'hypoxic respiratory failure may also contribute to the '
#                        'development of microhemorrhages. Cerebral gas embolism '
#                        'has been proposed as a cause of microhemorrhages in '
#                        'patients on venoarterial ECMO; this explanation is '
#                        'supported by the presence of microbleeds in the '
#                        'cerebral borderzone or watershed territories, often '
#                        'found in the right hemisphere, a finding suggestive of '
#                        'an embolic phenomenon. Patients requiring ECMO therapy '
#                        'are also at an increased risk of bleeding '
#                        'complications due to heparin coating of the ECMO '
#                        'equipment and systemic anticoagulation usually with '
#                        'unfractionated heparin. Furthermore, ECMO can lead to '
#                        'increased cerebral venous pressures, possibly related '
#                        'to positioning of the cannulae within the internal '
#                        'jugular vein, which can cause increased blood flow to '
#                        'the right atrium of the heart and, consequently, '
#                        'increased central venous pressure.'},
#               {'infons': {'section': 'Discussion',
#                           'section_type': 'DISCUSS',
#                           'type': 'paragraph'},
#                'offset': 7680,
#                'text': 'Endothelial dysfunction and immune response may be '
#                        'another cause of cerebral microhemorrhages. SARS-CoV-2 '
#                        'can directly enter endothelial cells by binding to the '
#                        'Angiotensin Converting Enzyme 2 receptor (ACE2), which '
#                        'is found in arterial and venous endothelial cells in a '
#                        'variety of human tissues including the brain, and can '
#                        'induce endotheliopathy, hypercoagulability, and '
#                        'microvascular leak. Patients with severe COVID-19 '
#                        'infection have shown elevated levels of '
#                        'pro-inflammatory cytokines, such as IL-2 and IL-6, '
#                        'which can bind to receptors on endothelial cells and '
#                        'induce capillary leakage and dysfunction, potentially '
#                        'leading to coagulation dysregulation, complement and '
#                        'platelet activation, thrombus formation, and '
#                        'potentially DIC. These mechanisms may help to explain '
#                        'the predisposition of COVID-19 patients to arterial '
#                        'and venous thromboembolism. In fact, acute ischemia '
#                        'was the most common imaging finding in COVID-19 '
#                        'patients who underwent brain imaging in recent '
#                        'retrospective studies from Italy and New York. '
#                        'However, despite being the most common COVID-19 '
#                        'related neuroimaging finding, acute stroke was still '
#                        'only found in 1.1% of 3218 hospitalized COVID-19 '
#                        'patients in the New York study.'},
#               {'infons': {'section': 'Discussion',
#                           'section_type': 'DISCUSS',
#                           'type': 'paragraph'},
#                'offset': 8881,
#                'text': 'Immune cell activation within the central nervous '
#                        'system can further lead to acute or chronic '
#                        'inflammation and brain damage. Infectious toxic '
#                        'encephalopathy, a reversible brain dysfunction '
#                        'syndrome due to systemic factors from acute infection, '
#                        'has been described in patients with COVID-19 and '
#                        'confirmed in autopsy reports. Recently, Poyiadji et '
#                        'al. described a case of acute hemorrhagic necrotizing '
#                        'encephalopathy occurring in a patient with COVID-19. '
#                        'While the exact pathomechanism for this entity has not '
#                        'been elucidated, it is thought to be most likely '
#                        'related to the development of an intracranial '
#                        '"cytokine storm", as a complication of viral infection '
#                        '(rather than direct viral invasion), causing '
#                        'blood-brain barrier breakdown, which can be detected '
#                        'on MRI as areas of edema, hemorrhage, and contrast '
#                        'enhancement.'},
#               {'infons': {'section': 'Discussion',
#                           'section_type': 'DISCUSS',
#                           'type': 'paragraph'},
#                'offset': 9704,
#                'text': 'Damage to the central nervous system can be related to '
#                        'direct viral invasion. Viral encephalitis caused by '
#                        'SARS-CoV-2 was recently confirmed with the detection '
#                        'of the virus in the cerebrospinal fluid of patients '
#                        'with COVID-19 by genome sequencing by a research team '
#                        'in China. Furthermore, infection of neuronal pathways '
#                        'by viruses may help to explain the symptoms of anosmia '
#                        '(where there is presumed involvement of the olfactory '
#                        'tract between the nasal epithelium and olfactory bulb) '
#                        'experienced by a subset of patients with COVID-19 '
#                        'infection.'},
#               {'infons': {'section': 'Discussion',
#                           'section_type': 'DISCUSS',
#                           'type': 'paragraph'},
#                'offset': 10249,
#                'text': 'Given the multiple potential causes of critical '
#                        'illness-associated cerebral microbleeds, the exact '
#                        'etiology for the microbleeds in our patient is not '
#                        'entirely clear, but it is most likely multifactorial '
#                        'and related to hypoxia, ECMO-related complications, '
#                        "and/or a coagulopathy disorder. Although the patient's "
#                        'coagulation labs were not entirely normal, he did not '
#                        'meet the criteria for overt disseminated intravascular '
#                        'coagulation. In addition, the absence of brain edema '
#                        'or acute infarcts on T2 FLAIR and DWI on MRI, '
#                        'respectively, argued against direct viral invasion, '
#                        'encephalitis, or other acute inflammatory, '
#                        'demyelinating, or ischemic processes. Although brain '
#                        'MRI can be normal in viral encephalitides, the '
#                        'clinical absence of an acute exacerbation of '
#                        'neurologic symptoms and lack of focal neurologic '
#                        'deficit in our patient did not support an acute '
#                        'infectious or inflammatory process of the brain '
#                        'parenchyma or meninges. Nonetheless, the correlation '
#                        'between cerebral microbleeds and neurocognitive '
#                        'impairment and disability in these patients is '
#                        'unclear. While elevated inflammatory serum markers '
#                        'such as D-dimer levels and the occurrence of acute '
#                        'strokes have been associated with poor prognosis in '
#                        'COVID-19 patients, prior reports of patients with '
#                        'acute respiratory distress syndrome treated with ECMO, '
#                        'including those with H1N1 influenza infection, had '
#                        'favorable clinical outcomes. At this time, the '
#                        'long-term clinical significance of cerebral '
#                        'microbleeds in patients with severe or critical '
#                        'COVID-19 infection remains to be seen. Therefore, it '
#                        'is important for radiologists and clinicians to '
#                        'recognize this entity in order to diagnosis and manage '
#                        'patients appropriately and to exercise caution when '
#                        'prognosticating patients based on these neuroimaging '
#                        'findings.'},
#               {'infons': {'section': 'Funding',
#                           'section_type': 'ACK_FUND',
#                           'type': 'title_1'},
#                'offset': 12020,
#                'text': 'Funding'},
#               {'infons': {'section': 'Funding',
#                           'section_type': 'ACK_FUND',
#                           'type': 'paragraph'},
#                'offset': 12028,
#                'text': 'None.'},
#               {'infons': {'section': 'Declaration of competing interest',
#                           'section_type': 'COMP_INT',
#                           'type': 'title_1'},
#                'offset': 12034,
#                'text': 'Declaration of competing interest'},
#               {'infons': {'section': 'Declaration of competing interest',
#                           'section_type': 'COMP_INT',
#                           'type': 'paragraph'},
#                'offset': 12068,
#                'text': 'Dr. Iv is a consultant for Octave Bioscience, Inc. '
#                        'which is unrelated to the submitted work. Dr. Gupta '
#                        'and Dr. Lien have no interests to declare.'},
#               {'infons': {'section': 'References',
#                           'section_type': 'REF',
#                           'type': 'title'},
#                'offset': 12214,
#                'text': 'References'},
#               {'infons': {'fpage': '1',
#                           'issue': '6',
#                           'lpage': '9',
#                           'name_0': 'surname:Mao;given-names:L.',
#                           'name_1': 'surname:Jin;given-names:H.',
#                           'name_2': 'surname:Wang;given-names:M.',
#                           'name_3': 'surname:Hu;given-names:Y.',
#                           'name_4': 'surname:Chen;given-names:S.',
#                           'name_5': 'surname:He;given-names:Q.',
#                           'section': 'References',
#                           'section_type': 'REF',
#                           'source': 'JAMA Neurol',
#                           'type': 'ref',
#                           'volume': '77',
#                           'year': '2020'},
#                'offset': 12225,
#                'text': 'Neurologic manifestations of hospitalized patients '
#                        'with coronavirus disease 2019 in Wuhan, China'},
#               {'infons': {'fpage': '2268',
#                           'issue': '23',
#                           'lpage': '2270',
#                           'name_0': 'surname:Helms;given-names:J.',
#                           'name_1': 'surname:Kremer;given-names:S.',
#                           'name_2': 'surname:Merdji;given-names:H.',
#                           'name_3': 'surname:Clere-Jehl;given-names:R.',
#                           'name_4': 'surname:Schenck;given-names:M.',
#                           'name_5': 'surname:Kummerlen;given-names:C.',
#                           'pub-id_pmid': '32294339',
#                           'section': 'References',
#                           'section_type': 'REF',
#                           'source': 'N Engl J Med',
#                           'type': 'ref',
#                           'volume': '382',
#                           'year': '2020'},
#                'offset': 12322,
#                'text': 'Neurologic features in severe SARS-CoV-2 infection'},
#               {'infons': {'comment': '[Online ahead of print]',
#                           'name_0': 'surname:Mahammedi;given-names:A.',
#                           'name_1': 'surname:Saba;given-names:L.',
#                           'name_2': 'surname:Vagal;given-names:A.',
#                           'name_3': 'surname:Leali;given-names:M.',
#                           'name_4': 'surname:Rossi;given-names:A.',
#                           'name_5': 'surname:Gaskill;given-names:M.',
#                           'pub-id_doi': '10.1148/radiol.2020201933',
#                           'section': 'References',
#                           'section_type': 'REF',
#                           'source': 'Radiology',
#                           'type': 'ref',
#                           'year': '2020'},
#                'offset': 12373,
#                'text': 'Imaging in neurological disease of hospitalized '
#                        'COVID-19 patients: an Italian multicenter '
#                        'retrospective observational study'},
#               {'infons': {'fpage': '201187',
#                           'name_0': 'surname:Poyiadji;given-names:N.',
#                           'name_1': 'surname:Shahin;given-names:G.',
#                           'name_2': 'surname:Noujaim;given-names:D.',
#                           'name_3': 'surname:Stone;given-names:M.',
#                           'name_4': 'surname:Patel;given-names:S.',
#                           'name_5': 'surname:Griffith;given-names:B.',
#                           'section': 'References',
#                           'section_type': 'REF',
#                           'source': 'Radiology',
#                           'type': 'ref',
#                           'year': '2020'},
#                'offset': 12497,
#                'text': 'COVID-19-associated acute hemorrhagic necrotizing '
#                        'encephalopathy: CT and MRI features'},
#               {'infons': {'fpage': '202040',
#                           'name_0': 'surname:Radmanesh;given-names:A.',
#                           'name_1': 'surname:Derman;given-names:A.',
#                           'name_2': 'surname:Lui;given-names:Y.W.',
#                           'name_3': 'surname:Raz;given-names:E.',
#                           'name_4': 'surname:Loh;given-names:J.P.',
#                           'name_5': 'surname:Hagiwara;given-names:M.',
#                           'pub-id_doi': '10.1148/radiol.2020202040',
#                           'section': 'References',
#                           'section_type': 'REF',
#                           'source': 'Radiology',
#                           'type': 'ref',
#                           'year': '2020'},
#                'offset': 12583,
#                'text': 'COVID-19-associated diffuse Leukoencephalopathy and '
#                        'microhemorrhages'},
#               {'infons': {'fpage': '202222',
#                           'name_0': 'surname:Kremer;given-names:S.',
#                           'name_1': 'surname:Lersy;given-names:F.',
#                           'name_2': 'surname:de Seze;given-names:J.',
#                           'name_3': 'surname:Ferre;given-names:J.C.',
#                           'name_4': 'surname:Maamar;given-names:A.',
#                           'name_5': 'surname:Carsin-Nicol;given-names:B.',
#                           'pub-id_doi': '10.1148/radiol.2020202222',
#                           'section': 'References',
#                           'section_type': 'REF',
#                           'source': 'Radiology',
#                           'type': 'ref',
#                           'year': '2020'},
#                'offset': 12652,
#                'text': 'Brain MRI findings in severe COVID-19: a retrospective '
#                        'observational study'},
#               {'infons': {'fpage': '1085',
#                           'issue': '4',
#                           'lpage': '1087',
#                           'name_0': 'surname:Fanou;given-names:E.M.',
#                           'name_1': 'surname:Coutinho;given-names:J.M.',
#                           'name_2': 'surname:Shannon;given-names:P.',
#                           'name_3': 'surname:Kiehl;given-names:T.R.',
#                           'name_4': 'surname:Levi;given-names:M.M.',
#                           'name_5': 'surname:Wilcox;given-names:M.E.',
#                           'pub-id_pmid': '28235962',
#                           'section': 'References',
#                           'section_type': 'REF',
#                           'source': 'Stroke',
#                           'type': 'ref',
#                           'volume': '48',
#                           'year': '2017'},
#                'offset': 12727,
#                'text': 'Critical illness-associated cerebral microbleeds'},
#               {'infons': {'fpage': '2782',
#                           'issue': '10',
#                           'lpage': '2786',
#                           'name_0': 'surname:Cheng;given-names:A.L.',
#                           'name_1': 'surname:Batool;given-names:S.',
#                           'name_2': 'surname:McCreary;given-names:C.R.',
#                           'name_3': 'surname:Lauzon;given-names:M.L.',
#                           'name_4': 'surname:Frayne;given-names:R.',
#                           'name_5': 'surname:Goyal;given-names:M.',
#                           'pub-id_pmid': '23920014',
#                           'section': 'References',
#                           'section_type': 'REF',
#                           'source': 'Stroke',
#                           'type': 'ref',
#                           'volume': '44',
#                           'year': '2013'},
#                'offset': 12776,
#                'text': 'Susceptibility-weighted imaging is more reliable than '
#                        'T2*-weighted gradient-recalled echo MRI for detecting '
#                        'microbleeds'},
#               {'infons': {'fpage': '11',
#                           'issue': '1',
#                           'lpage': '28',
#                           'name_0': 'surname:Haller;given-names:S.',
#                           'name_1': 'surname:Vernooij;given-names:M.W.',
#                           'name_2': 'surname:Kuijer;given-names:J.P.A.',
#                           'name_3': 'surname:Larsson;given-names:E.M.',
#                           'name_4': 'surname:Jager;given-names:H.R.',
#                           'name_5': 'surname:Barkhof;given-names:F.',
#                           'pub-id_pmid': '29558307',
#                           'section': 'References',
#                           'section_type': 'REF',
#                           'source': 'Radiology',
#                           'type': 'ref',
#                           'volume': '287',
#                           'year': '2018'},
#                'offset': 12896,
#                'text': 'Cerebral microbleeds: imaging and clinical '
#                        'significance'},
#               {'infons': {'fpage': '24',
#                           'issue': '1',
#                           'lpage': '33',
#                           'name_0': 'surname:Levi;given-names:M.',
#                           'name_1': 'surname:Toh;given-names:C.H.',
#                           'name_2': 'surname:Thachil;given-names:J.',
#                           'name_3': 'surname:Watson;given-names:H.G.',
#                           'pub-id_pmid': '19222477',
#                           'section': 'References',
#                           'section_type': 'REF',
#                           'source': 'British Committee for Standards in '
#                                     'Haematology Br J Haematol',
#                           'type': 'ref',
#                           'volume': '145',
#                           'year': '2009'},
#                'offset': 12952,
#                'text': 'Guidelines for the diagnosis and management of '
#                        'disseminated intravascular coagulation'},
#               {'infons': {'fpage': '156',
#                           'issue': '1',
#                           'lpage': '160',
#                           'name_0': 'surname:Chow;given-names:F.C.',
#                           'name_1': 'surname:Edlow;given-names:B.L.',
#                           'name_2': 'surname:Frosch;given-names:M.P.',
#                           'name_3': 'surname:Copen;given-names:W.A.',
#                           'name_4': 'surname:Greer;given-names:D.M.',
#                           'pub-id_pmid': '21465323',
#                           'section': 'References',
#                           'section_type': 'REF',
#                           'source': 'Neurocrit Care',
#                           'type': 'ref',
#                           'volume': '15',
#                           'year': '2011'},
#                'offset': 13038,
#                'text': 'Outcome in patients with H1N1 influenza and '
#                        'cerebrovascular injury treated with extracorporeal '
#                        'membrane oxygenation'},
#               {'infons': {'fpage': '1635',
#                           'issue': '9',
#                           'lpage': '1642',
#                           'name_0': 'surname:Kallenberg;given-names:K.',
#                           'name_1': 'surname:Dehnert;given-names:C.',
#                           'name_2': 'surname:Dorfler;given-names:A.',
#                           'name_3': 'surname:Schellinger;given-names:P.D.',
#                           'name_4': 'surname:Bailey;given-names:D.M.',
#                           'name_5': 'surname:Knauth;given-names:M.',
#                           'pub-id_pmid': '18523438',
#                           'section': 'References',
#                           'section_type': 'REF',
#                           'source': 'J Cereb Blood Flow Metab',
#                           'type': 'ref',
#                           'volume': '28',
#                           'year': '2008'},
#                'offset': 13154,
#                'text': 'Microhemorrhages in nonfatal high-altitude cerebral '
#                        'edema'},
#               {'infons': {'fpage': 'e386',
#                           'issue': '9',
#                           'lpage': 'e389',
#                           'name_0': 'surname:Riech;given-names:S.',
#                           'name_1': 'surname:Kallenberg;given-names:K.',
#                           'name_2': 'surname:Moerer;given-names:O.',
#                           'name_3': 'surname:Hellen;given-names:P.',
#                           'name_4': 'surname:Bartsch;given-names:P.',
#                           'name_5': 'surname:Quintel;given-names:M.',
#                           'pub-id_pmid': '26110491',
#                           'section': 'References',
#                           'section_type': 'REF',
#                           'source': 'Crit Care Med',
#                           'type': 'ref',
#                           'volume': '43',
#                           'year': '2015'},
#                'offset': 13212,
#                'text': 'The pattern of brain microhemorrhages after severe '
#                        'lung failure resembles the one seen in high-altitude '
#                        'cerebral edema'},
#               {'infons': {'fpage': '75',
#                           'issue': '1',
#                           'lpage': '78',
#                           'name_0': 'surname:Liebeskind;given-names:D.S.',
#                           'name_1': 'surname:Sanossian;given-names:N.',
#                           'name_2': 'surname:Sapo;given-names:M.L.',
#                           'name_3': 'surname:Saver;given-names:J.L.',
#                           'pub-id_pmid': '22606942',
#                           'section': 'References',
#                           'section_type': 'REF',
#                           'source': 'J Neuroimaging',
#                           'type': 'ref',
#                           'volume': '23',
#                           'year': '2013'},
#                'offset': 13331,
#                'text': 'Cerebral microbleeds after use of extracorporeal '
#                        'membrane oxygenation in children'},
#               {'infons': {'fpage': '353',
#                           'issue': '1',
#                           'name_0': 'surname:Pons;given-names:S.',
#                           'name_1': 'surname:Fodil;given-names:S.',
#                           'name_2': 'surname:Azoulay;given-names:E.',
#                           'name_3': 'surname:Zafrani;given-names:L.',
#                           'pub-id_pmid': '32546188',
#                           'section': 'References',
#                           'section_type': 'REF',
#                           'source': 'Crit Care',
#                           'type': 'ref',
#                           'volume': '24',
#                           'year': '2020'},
#                'offset': 13413,
#                'text': 'The vascular endothelium: the cornerstone of organ '
#                        'dysfunction in severe SARS-CoV-2 infection'},
#               {'infons': {'name_0': 'surname:Jain;given-names:R.',
#                           'name_1': 'surname:Young;given-names:M.',
#                           'name_2': 'surname:Dogra;given-names:S.',
#                           'name_3': 'surname:Kennedy;given-names:H.',
#                           'name_4': 'surname:Nguyen;given-names:V.',
#                           'name_5': 'surname:Jones;given-names:S.',
#                           'section': 'References',
#                           'section_type': 'REF',
#                           'source': 'J Neurol Sci',
#                           'type': 'ref',
#                           'volume': '414',
#                           'year': '2020'},
#                'offset': 13507,
#                'text': 'COVID-19 related neuroimaging findings: a signal of '
#                        'thromboembolic complications and a strong prognostic '
#                        'marker of poor patient outcome'},
#               {'infons': {'fpage': '647',
#                           'issue': '6',
#                           'lpage': '648',
#                           'name_0': 'surname:Mankad;given-names:K.',
#                           'name_1': 'surname:Perry;given-names:M.D.',
#                           'name_2': 'surname:Mirsky;given-names:D.M.',
#                           'name_3': 'surname:Rossi;given-names:A.',
#                           'pub-id_pmid': '32342126',
#                           'section': 'References',
#                           'section_type': 'REF',
#                           'source': 'Neuroradiology',
#                           'type': 'ref',
#                           'volume': '62',
#                           'year': '2020'},
#                'offset': 13643,
#                'text': 'COVID-19: a primer for Neuroradiologists'},
#               {'infons': {'fpage': '18',
#                           'lpage': '22',
#                           'name_0': 'surname:Wu;given-names:Y.',
#                           'name_1': 'surname:Xu;given-names:X.',
#                           'name_2': 'surname:Chen;given-names:Z.',
#                           'name_3': 'surname:Duan;given-names:J.',
#                           'name_4': 'surname:Hashimoto;given-names:K.',
#                           'name_5': 'surname:Yang;given-names:L.',
#                           'pub-id_pmid': '32240762',
#                           'section': 'References',
#                           'section_type': 'REF',
#                           'source': 'Brain Behav Immun',
#                           'type': 'ref',
#                           'volume': '87',
#                           'year': '2020'},
#                'offset': 13684,
#                'text': 'Nervous system involvement after infection with '
#                        'COVID-19 and other coronaviruses'},
#               {'infons': {'fpage': '84',
#                           'issue': '1',
#                           'name_0': 'surname:Gilden;given-names:D.H.',
#                           'pub-id_pmid': '18166713',
#                           'section': 'References',
#                           'section_type': 'REF',
#                           'source': 'Neurology',
#                           'type': 'ref',
#                           'volume': '70',
#                           'year': '2008'},
#                'offset': 13765,
#                'text': 'Brain imaging abnormalities in CNS virus infections'},
#               {'infons': {'fpage': '594',
#                           'issue': '5',
#                           'lpage': '596',
#                           'name_0': 'surname:Le Guennec;given-names:L.',
#                           'name_1': 'surname:Bertrand;given-names:A.',
#                           'name_2': 'surname:Laurent;given-names:C.',
#                           'name_3': 'surname:Roze;given-names:H.',
#                           'name_4': 'surname:Chastre;given-names:J.',
#                           'name_5': 'surname:Combes;given-names:A.',
#                           'pub-id_pmid': '25723825',
#                           'section': 'References',
#                           'section_type': 'REF',
#                           'source': 'Am J Respir Crit Care Med',
#                           'type': 'ref',
#                           'volume': '191',
#                           'year': '2015'},
#                'offset': 13817,
#                'text': 'Diffuse cerebral microbleeds after extracorporeal '
#                        'membrane oxygenation support'},
#               {'infons': {'section': 'References',
#                           'section_type': 'REF',
#                           'type': 'footnote'},
#                'offset': 13896,
#                'text': 'Name and street address of the institution from which '
#                        'the work originated: Regional Medical Center, 225 N '
#                        'Jackson Ave, San Jose, CA 95116.'}],
#  'pmcid': 'PMC7832150',
#  'pmid': 32911311,
#  'year': 2020}

# %%
# Count the number of publications for each journal. Sort the result in descending order and print journals with more than 4 publications

# fill in (10 pts)
result3= posts.aggregate([
    {"$group": {"_id": "$journal", "count": {"$sum": 1}}},
    {"$match": {"count": {"$gt": 4}}},
    {"$sort": {"count": -1}}
])
for post in result3:
    pprint.pprint(post)
# Out:
# {'_id': '', 'count': 137}
# {'_id': 'BMJ', 'count': 12}
# {'_id': 'Nature', 'count': 10}
# {'_id': 'PLoS One', 'count': 9}
# {'_id': 'Cureus', 'count': 7}
# {'_id': 'Sci Rep', 'count': 6}
# {'_id': 'Gastroenterology', 'count': 5}
# {'_id': 'N Engl J Med', 'count': 5}
# {'_id': 'Am J Infect Control', 'count': 5}

# %%
# Find all papers published in PLoS One journal. Print their years and titles
# fill in (10 pts)
result4= posts.find({"journal": "PLoS One"})
for post in result4:
    pprint.pprint(post['passages'][0]['infons']['year'])
    pprint.pprint(post['passages'][0]['text'])
# Out:
# '2021'
# ('Sex differences in susceptibility, severity, and outcomes of coronavirus '
#  'disease 2019: Cross-sectional analysis from a diverse US metropolitan area')
# '2021'
# ('Correction: Comparative analysis of various clinical specimens in detection '
#  'of SARS-CoV-2 using rRT-PCR in new and follow up cases of COVID-19 '
#  'infection: Quest for the best choice.')
# '2020'
# "A synthetic indicator on the impact of COVID-19 on the community's health."
# '2021'
# 'SARS-CoV-2 infection in asymptomatic healthcare workers at a clinic in Chile'
# '2021'
# ('Are older adults of Rohingya community (Forcibly Displaced Myanmar Nationals '
#  'or FDMNs) in Bangladesh fearful of COVID-19? Findings from a cross-sectional '
#  'study')
# '2021'
# ('Closed for business: The mortality impact of business closures during the '
#  'Covid-19 pandemic')
# '2020'
# ('Persistence of symptoms and quality of life at 35 days after hospitalization '
#  'for COVID-19 infection')
# '2021'
# ('Factors indicating intention to vaccinate with a COVID-19 vaccine among '
#  'older U.S. adults')
# '2020'
# ('Multi-resolution visualization and analysis of biomolecular networks through '
#  'hierarchical community detection and web-based graphical tools')

# %%
# Count the number of publications for each author. Sort the results in descending order and return authors with 5 or more publications
# fill in (10 pts)
result5= posts.aggregate([{"$unwind": "$authors"}, {"$group": {"_id": "$authors", "count": {"$sum": 1}}}, {"$match": {"count": {"$gte": 5}}}, {"$sort": {"count": -1}}])
for post in result5:
    pprint.pprint(post)
# Out:
# {'_id': 'Zhang Y', 'count': 12}
# {'_id': 'Wang J', 'count': 8}
# {'_id': 'Wang S', 'count': 7}
# {'_id': 'Zhang J', 'count': 7}
# {'_id': 'Li X', 'count': 7}
# {'_id': 'Yang Y', 'count': 7}
# {'_id': 'Zhang L', 'count': 7}
# {'_id': 'Li Y', 'count': 7}
# {'_id': 'Li H', 'count': 6}
# {'_id': 'Zhang X', 'count': 6}
# {'_id': 'Wang Z', 'count': 6}
# {'_id': 'Liu Y', 'count': 6}
# {'_id': 'Li J', 'count': 6}
# {'_id': 'Zheng Y', 'count': 5}
# {'_id': 'Shi Y', 'count': 5}
# {'_id': 'Liu J', 'count': 5}
# {'_id': 'Wang X', 'count': 5}
# {'_id': 'Wang Y', 'count': 5}

# %%
# Find the papers co-written by ‘Wang J’ and 'Zhang L', print the paper pmids, journal names and titles
# fill in (10 pts)
result6 = posts.find({"authors": {"$all": ["Wang J", "Zhang L"]}})
for post in result6:
    pprint.pprint(post['pmid'])
    pprint.pprint(post['journal'])
    pprint.pprint(post['passages'][0]['text'])
# Out:
# 34124189
# 'Front Cardiovasc Med'
# ('Early vs. Late Onset Cardiac Injury and Mortality in Hospitalized COVID-19 '
#  'Patients in Wuhan.')
# 34184314
# 'Echocardiography'
# ('Incremental prognostic value of biventricular longitudinal strain and '
#  'high-sensitivity troponin I in COVID-19 patients.')

# %%
# Create text index on passages.text
# fill in
posts.create_index([("passages.text", "text")])
# Out:
# 'passages.text_text'

# %%
# count the number of publications that contains the phrase "COVID-19 Vaccine"
# fill in (10 pts)
result7= posts.count_documents({"$text": {"$search": "\"COVID-19 Vaccine\""}})
print("Count the number of publications that contains the phrase 'COVID-19 Vaccine'", result7)
# Out:
# Count the number of publications that contains the phrase 'COVID-19 Vaccine' 46

# %%
# count the number of publications that contains the words "COVID-19" or "Sars-CoV-2"
# fill in (10 pts)
result8= posts.count_documents({"$text": {"$search": "COVID-19 Sars-CoV-2"}})
print("Count the number of publications that contains the words 'COVID-19' or 'Sars-CoV-2'", result8)
# Out:
# Count the number of publications that contains the words 'COVID-19' or 'Sars-CoV-2' 957

# %%
# count the number of publications that contains the words "COVID-19" and "Sars-CoV-2"
# fill in (10 pts)
result9= posts.count_documents({"$text": {"$search": "\"COVID-19\" \"Sars-CoV-2\""}})
print("Count the number of publications that contains the words 'COVID-19' and 'Sars-CoV-2'", result9)
# Out:
# Count the number of publications that contains the words 'COVID-19' and 'Sars-CoV-2' 384
